# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer ="online_retail.csv")

# %%
online_retail = df = pd.read_csv(filepath_or_buffer = "online_retail.csv")

# %%
online_retail
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A                  Unknown Description         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 9994    537233     22439                   6 ROCKET BALLOONS         24
# 9995    537233     21844                    RED RETROSPOT MUG        12
# 9996    537233     22812     PACK 3 BOXES CHRISTMAS PANNETONE        24
# 9997   C537234     22653                          BUTTON BOX        -20
# 9998    537235     22622       BOX OF VINTAGE ALPHABET BLOCKS       156
#
#      InvoiceDate  UnitPrice CustomerID         Country
# 0     01-12-2010       2.55      17850  United Kingdom
# 1     01-12-2010       3.39      17850  United Kingdom
# 2     01-12-2010       2.75      17850  United Kingdom
# 3     01-12-2010       3.39      17850  United Kingdom
# 4     01-12-2010       3.39      17850  United Kingdom
# ...          ...        ...        ...             ...
# 9994  06-12-2010       0.65      17428  United Kingdom
# 9995  06-12-2010       2.95      17428  United Kingdom
# 9996  06-12-2010       1.95      17428  United Kingdom
# 9997  06-12-2010       1.95      16161  United Kingdom
# 9998  06-12-2010       8.50      17381  United Kingdom
#
# [9999 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    9999 non-null   object
#  1   StockCode    9999 non-null   object
#  2   Description  9999 non-null   object
#  3   Quantity     9999 non-null   int64
#  4   InvoiceDate  9999 non-null   object
#  5   UnitPrice    9999 non-null   float64
#  6   CustomerID   9999 non-null   object
#  7   Country      9999 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 625.1+ KB

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Quantity    UnitPrice
# count  9999.000000  9999.000000
# mean      7.985999     3.844477
# std     104.359602    14.311980
# min   -9360.000000     0.000000
# 25%       1.000000     1.250000
# 50%       3.000000     2.510000
# 75%       8.000000     4.210000
# max    2880.000000   887.520000

# %%
df['sales'] = df['Quantity'] * df['UnitPrice']
df['sales'].sum()
# Out:
# np.float64(184102.12)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
country_sales = df.groupby('Country')['sales'].sum().sort_values(ascending=False)
country_sales.head(10)
# Out:
# Country
# United Kingdom    168388.59
# Germany             3309.75
# EIRE                3147.23
# France              2808.16
# Norway              1919.14
# Lithuania           1598.06
# Spain                620.00
# Italy                410.80
# Australia            358.25
# Belgium              346.10
# Name: sales, dtype: float64

# %%
product_sales = df.groupby('Description')['sales'].sum().sort_values(ascending=False)
product_sales.head(10)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              7717.95
# RED WOOLLY HOTTIE WHITE HEART.        3186.63
# DOTCOM POSTAGE                        2938.74
# WHITE HANGING HEART T-LIGHT HOLDER    2858.03
# CHILLI LIGHTS                         2759.68
# PAPER CHAIN KIT 50'S CHRISTMAS        2412.77
# BLACK RECORD COVER FRAME              2159.79
# SET 7 BABUSHKA NESTING BOXES          2005.96
# RED  HARMONICA IN BOX                 1832.82
# BOX OF VINTAGE ALPHABET BLOCKS        1557.51
# Name: sales, dtype: float64

# %%
customer_sales = df.groupby('CustomerID')['sales'].sum().sort_values(ascending=False)
customer_sales.head(10)
# Out:
# CustomerID
# Unknown Customer    36044.45
# 15061                9407.34
# 13777                6585.16
# 17850                5391.21
# 16029                4271.52
# 16210                2474.74
# 13081                2366.78
# 17381                2362.08
# 14911                2283.53
# 16754                2002.40
# Name: sales, dtype: float64

# %%
product_quantity = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False)
product_quantity.head(10)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     3409
# ASSORTED COLOUR T-LIGHT HOLDER        1854
# RED  HARMONICA IN BOX                 1672
# ASSORTED INCENSE PACK                 1440
# PACK OF 72 RETROSPOT CAKE CASES       1095
# WHITE HANGING HEART T-LIGHT HOLDER    1015
# ASSORTED COLOUR BIRD ORNAMENT          904
# RED WOOLLY HOTTIE WHITE HEART.         829
# BROCADE RING PURSE                     798
# JUMBO BAG RED RETROSPOT                792
# Name: Quantity, dtype: int64

# %%
df['InvoiceDate'].head()
# Out:
# 0    01-12-2010
# 1    01-12-2010
# 2    01-12-2010
# 3    01-12-2010
# 4    01-12-2010
# Name: InvoiceDate, dtype: object

# %%
df['InvoiceDate'] = pd.to_datetime(
    df['InvoiceDate'],
    format='%d-%m-%y'
)
df['month'] = df['InvoiceDate'].dt.to_period('M')
monthly_sales = df.groupby('month')['sales'].sum()
monthly_sales
# Out:
# month
# 2010-12    184102.12
# Freq: M, Name: sales, dtype: float64

# %% [markdown]
# ### python visualization

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.plot(
    daily_sales.index.astype(str),
    daily_sales.values,
    marker='o'
)

plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
top_products = df.groupby('Description')['sales'].sum().sort_values(ascending=False).head(10)
print(top_products)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              7717.95
# RED WOOLLY HOTTIE WHITE HEART.        3186.63
# DOTCOM POSTAGE                        2938.74
# WHITE HANGING HEART T-LIGHT HOLDER    2858.03
# CHILLI LIGHTS                         2759.68
# PAPER CHAIN KIT 50'S CHRISTMAS        2412.77
# BLACK RECORD COVER FRAME              2159.79
# SET 7 BABUSHKA NESTING BOXES          2005.96
# RED  HARMONICA IN BOX                 1832.82
# BOX OF VINTAGE ALPHABET BLOCKS        1557.51
# Name: sales, dtype: float64

# %%
top_products = df.groupby('Description')['sales'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar')

plt.title('Top 10 Products by Sales')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
top_countries = df.groupby('Country')['sales'].sum().sort_values(ascending=False).head(10)

top_countries
# Out:
# Country
# United Kingdom    168388.59
# Germany             3309.75
# EIRE                3147.23
# France              2808.16
# Norway              1919.14
# Lithuania           1598.06
# Spain                620.00
# Italy                410.80
# Australia            358.25
# Belgium              346.10
# Name: sales, dtype: float64

# %%
top_countries.plot(kind='bar')

plt.title('Top 10 Countries by Sales')
plt.xlabel('Country')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
top_customers = df.groupby('CustomerID')['sales'].sum().sort_values(ascending=False).head(10)

top_customers
# Out:
# CustomerID
# Unknown Customer    36044.45
# 15061                9407.34
# 13777                6585.16
# 17850                5391.21
# 16029                4271.52
# 16210                2474.74
# 13081                2366.78
# 17381                2362.08
# 14911                2283.53
# 16754                2002.40
# Name: sales, dtype: float64

# %%
top_customers.plot(kind='bar')

plt.title('Top 10 Customers by Sales')
plt.xlabel('Customer ID')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
total_sales = df['sales'].sum()

total_orders = df['InvoiceNo'].nunique()

total_customers = df['CustomerID'].nunique()

total_products = df['Description'].nunique()

print("Total Sales:", total_sales)
print("Total Orders:", total_orders)
print("Total Customers:", total_customers)
print("Total Products:", total_products)
# Out:
# Total Sales: 184102.12
# Total Orders: 523
# Total Customers: 330
# Total Products: 2000

# %%
average_order_value = total_sales / total_orders

print("Average Order Value:", average_order_value)
# Out:
# Average Order Value: 352.0117017208413

# %%
total_quantity = df['Quantity'].sum()

print("Total Quantity Sold:", total_quantity)
# Out:
# Total Quantity Sold: 79852

# %%
country_sales = df.groupby('Country')['sales'].sum().sort_values(ascending=False)

print(country_sales.head(10))
# Out:
# Country
# United Kingdom    168388.59
# Germany             3309.75
# EIRE                3147.23
# France              2808.16
# Norway              1919.14
# Lithuania           1598.06
# Spain                620.00
# Italy                410.80
# Australia            358.25
# Belgium              346.10
# Name: sales, dtype: float64

# %%
print("Total Sales:", round(total_sales, 2))
print("Total Orders:", total_orders)
print("Total Customers:", total_customers)
print("Total Products:", total_products)
print("Average Order Value:", round(average_order_value, 2))
print("Total Quantity Sold:", total_quantity)
# Out:
# Total Sales: 184102.12
# Total Orders: 523
# Total Customers: 330
# Total Products: 2000
# Average Order Value: 352.01
# Total Quantity Sold: 79852

# %%
df.to_csv('cleaned_online_retail.csv', index=False)

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Swaminathan v\Downloads\python\online_retail_data
